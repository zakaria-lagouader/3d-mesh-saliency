# %%
import tensorflow as tf
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.losses import LogCosh
from keras.metrics import MeanSquaredError, MeanAbsoluteError,RootMeanSquaredError
from keras import Sequential, layers
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
# Out:
# 2024-08-20 13:07:33.657714: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-20 13:07:33.657815: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-20 13:07:33.794713: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Hyper parameters
PATCH_SIZE = 64
BATCH_SIZE = 200
EPOCHS = 80

# %%
val_files = {
    "../patches-64/skull_decimated.npy", 
    "../patches-64/ant_decimated.npy", 
    "../patches-64/vase_decimated.npy", 
    "../patches-64/isis_decimated.npy", 
    "../patches-64/teddy_decimated.npy",
    "../patches-64/teapot_decimated.npy"
}

patche_files = sorted(glob.glob('../patches-64/*.npy'))
patche_files = list(set(patche_files) - val_files)
saliency_files = [
    f"../3d-meshes/{os.path.basename(f).replace('.npy', '.txt')}" 
    for f in patche_files
]

print('Number of patches:', len(patche_files))
print('Number of saliency maps:', len(saliency_files))
# Out:
# Number of patches: 43
# Number of saliency maps: 43

# %%
X_train = np.concatenate([np.load(f, mmap_mode="r").astype(np.uint8) for f in patche_files])
y_train = np.concatenate([np.loadtxt(f).astype(np.float32) for f in saliency_files])
    
X_train, y_train = shuffle(X_train, y_train)
X_train.shape, y_train.shape, X_train.dtype, y_train.dtype
# Out:
# ((859999, 64, 64, 3), (859999,), dtype('uint8'), dtype('float32'))

# %%
tf.keras.mixed_precision.set_global_policy('mixed_float16')
model = Sequential()

model.add(layers.Conv2D(filters = 16, kernel_size = (3,3), activation ='relu',
                        input_shape=(PATCH_SIZE, PATCH_SIZE, 3), padding="same", strides=(1, 1)))
model.add(layers.BatchNormalization(axis=3))
model.add(layers.Conv2D(filters = 16, kernel_size = (3,3), activation ='relu', padding="same", strides=(1, 1)))
model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2, 2), padding="valid"))
model.add(layers.BatchNormalization(axis=3))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters = 32, kernel_size = (3,3), activation ='relu', padding="same", strides=(1, 1)))
model.add(layers.BatchNormalization(axis=3))
model.add(layers.Conv2D(filters = 32, kernel_size = (3,3), activation ='relu', padding="same", strides=(1, 1)))
model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2, 2), padding="valid"))
model.add(layers.BatchNormalization(axis=3))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters = 64, kernel_size = (3,3), activation ='relu', padding="same", strides=(1, 1)))
model.add(layers.BatchNormalization(axis=3))
model.add(layers.Conv2D(filters = 64, kernel_size = (3,3), activation ='relu', padding="same", strides=(1, 1)))
model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2, 2), padding="valid"))
model.add(layers.BatchNormalization(axis=3))
model.add(layers.Dropout(0.25))

model.add(layers.Flatten())

model.add(layers.Dense(256, activation = "relu")) #Fully connected layer
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(64, activation = "relu")) #Fully connected layer
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation = "sigmoid")) # output layer

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
optimizer = tf.keras.mixed_precision.LossScaleOptimizer(optimizer)

model.compile(optimizer=optimizer, loss=LogCosh(), metrics=[
            MeanSquaredError(name='mse'),
            MeanAbsoluteError(name='mae'),
            RootMeanSquaredError(name='rmse'),
])

model.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 64, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 64, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,048,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,139,601 (4.35 MB)
#  Trainable params: 1,138,513 (4.34 MB)
#  Non-trainable params: 1,088 (4.25 KB)

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# fit the model
saliency_model = model.fit(
    X_train, y_train, 
    batch_size=BATCH_SIZE, 
    epochs=EPOCHS, 
    validation_split=0.2, 
    verbose=1,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/80
#    6/3440 ━━━━━━━━━━━━━━━━━━━━ 1:23 24ms/step - loss: 0.1378 - mae: 0.4590 - mse: 0.3007 - rmse: 0.5483
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724159421.117281      82 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 106s 23ms/step - loss: 0.0590 - mae: 0.2579 - mse: 0.1275 - rmse: 0.3498 - val_loss: 0.0166 - val_mae: 0.1143 - val_mse: 0.0355 - val_rmse: 0.1885 - learning_rate: 1.0000e-04
# Epoch 2/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0176 - mae: 0.1138 - mse: 0.0378 - rmse: 0.1943 - val_loss: 0.0141 - val_mae: 0.1030 - val_mse: 0.0299 - val_rmse: 0.1729 - learning_rate: 1.0000e-04
# Epoch 3/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0145 - mae: 0.1035 - mse: 0.0308 - rmse: 0.1754 - val_loss: 0.0126 - val_mae: 0.0986 - val_mse: 0.0266 - val_rmse: 0.1630 - learning_rate: 1.0000e-04
# Epoch 4/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0128 - mae: 0.0985 - mse: 0.0268 - rmse: 0.1636 - val_loss: 0.0113 - val_mae: 0.0896 - val_mse: 0.0237 - val_rmse: 0.1539 - learning_rate: 1.0000e-04
# Epoch 5/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0114 - mae: 0.0923 - mse: 0.0238 - rmse: 0.1542 - val_loss: 0.0094 - val_mae: 0.0817 - val_mse: 0.0194 - val_rmse: 0.1393 - learning_rate: 1.0000e-04
# Epoch 6/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0102 - mae: 0.0865 - mse: 0.0211 - rmse: 0.1452 - val_loss: 0.0084 - val_mae: 0.0778 - val_mse: 0.0175 - val_rmse: 0.1321 - learning_rate: 1.0000e-04
# Epoch 7/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0089 - mae: 0.0807 - mse: 0.0185 - rmse: 0.1360 - val_loss: 0.0073 - val_mae: 0.0711 - val_mse: 0.0151 - val_rmse: 0.1230 - learning_rate: 1.0000e-04
# Epoch 8/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0079 - mae: 0.0762 - mse: 0.0164 - rmse: 0.1280 - val_loss: 0.0061 - val_mae: 0.0649 - val_mse: 0.0125 - val_rmse: 0.1120 - learning_rate: 1.0000e-04
# Epoch 9/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0072 - mae: 0.0722 - mse: 0.0148 - rmse: 0.1216 - val_loss: 0.0054 - val_mae: 0.0646 - val_mse: 0.0111 - val_rmse: 0.1052 - learning_rate: 1.0000e-04
# Epoch 10/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 16ms/step - loss: 0.0066 - mae: 0.0691 - mse: 0.0135 - rmse: 0.1162 - val_loss: 0.0051 - val_mae: 0.0608 - val_mse: 0.0105 - val_rmse: 0.1025 - learning_rate: 1.0000e-04
# Epoch 11/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0061 - mae: 0.0663 - mse: 0.0125 - rmse: 0.1117 - val_loss: 0.0048 - val_mae: 0.0575 - val_mse: 0.0097 - val_rmse: 0.0985 - learning_rate: 1.0000e-04
# Epoch 12/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0057 - mae: 0.0638 - mse: 0.0117 - rmse: 0.1080 - val_loss: 0.0042 - val_mae: 0.0536 - val_mse: 0.0085 - val_rmse: 0.0924 - learning_rate: 1.0000e-04
# Epoch 13/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0054 - mae: 0.0618 - mse: 0.0109 - rmse: 0.1046 - val_loss: 0.0040 - val_mae: 0.0523 - val_mse: 0.0082 - val_rmse: 0.0904 - learning_rate: 1.0000e-04
# Epoch 14/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0051 - mae: 0.0603 - mse: 0.0104 - rmse: 0.1019 - val_loss: 0.0035 - val_mae: 0.0493 - val_mse: 0.0072 - val_rmse: 0.0849 - learning_rate: 1.0000e-04
# Epoch 15/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0048 - mae: 0.0585 - mse: 0.0098 - rmse: 0.0990 - val_loss: 0.0035 - val_mae: 0.0500 - val_mse: 0.0072 - val_rmse: 0.0847 - learning_rate: 1.0000e-04
# Epoch 16/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0046 - mae: 0.0572 - mse: 0.0094 - rmse: 0.0968 - val_loss: 0.0031 - val_mae: 0.0471 - val_mse: 0.0064 - val_rmse: 0.0799 - learning_rate: 1.0000e-04
# Epoch 17/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 16ms/step - loss: 0.0044 - mae: 0.0560 - mse: 0.0090 - rmse: 0.0947 - val_loss: 0.0029 - val_mae: 0.0452 - val_mse: 0.0058 - val_rmse: 0.0759 - learning_rate: 1.0000e-04
# Epoch 18/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0042 - mae: 0.0547 - mse: 0.0086 - rmse: 0.0925 - val_loss: 0.0028 - val_mae: 0.0439 - val_mse: 0.0056 - val_rmse: 0.0751 - learning_rate: 1.0000e-04
# Epoch 19/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0041 - mae: 0.0538 - mse: 0.0082 - rmse: 0.0908 - val_loss: 0.0027 - val_mae: 0.0427 - val_mse: 0.0054 - val_rmse: 0.0737 - learning_rate: 1.0000e-04
# Epoch 20/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0039 - mae: 0.0527 - mse: 0.0080 - rmse: 0.0892 - val_loss: 0.0025 - val_mae: 0.0430 - val_mse: 0.0050 - val_rmse: 0.0709 - learning_rate: 1.0000e-04
# Epoch 21/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0038 - mae: 0.0518 - mse: 0.0077 - rmse: 0.0875 - val_loss: 0.0025 - val_mae: 0.0426 - val_mse: 0.0051 - val_rmse: 0.0717 - learning_rate: 1.0000e-04
# Epoch 22/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0037 - mae: 0.0509 - mse: 0.0074 - rmse: 0.0862 - val_loss: 0.0024 - val_mae: 0.0412 - val_mse: 0.0048 - val_rmse: 0.0695 - learning_rate: 1.0000e-04
# Epoch 23/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0035 - mae: 0.0503 - mse: 0.0072 - rmse: 0.0848 - val_loss: 0.0023 - val_mae: 0.0406 - val_mse: 0.0047 - val_rmse: 0.0685 - learning_rate: 1.0000e-04
# Epoch 24/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 16ms/step - loss: 0.0035 - mae: 0.0495 - mse: 0.0070 - rmse: 0.0837 - val_loss: 0.0021 - val_mae: 0.0387 - val_mse: 0.0042 - val_rmse: 0.0651 - learning_rate: 1.0000e-04
# Epoch 25/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0034 - mae: 0.0490 - mse: 0.0069 - rmse: 0.0829 - val_loss: 0.0020 - val_mae: 0.0380 - val_mse: 0.0040 - val_rmse: 0.0634 - learning_rate: 1.0000e-04
# Epoch 26/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 82s 16ms/step - loss: 0.0033 - mae: 0.0481 - mse: 0.0066 - rmse: 0.0812 - val_loss: 0.0022 - val_mae: 0.0390 - val_mse: 0.0044 - val_rmse: 0.0663 - learning_rate: 1.0000e-04
# Epoch 27/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0032 - mae: 0.0477 - mse: 0.0065 - rmse: 0.0805 - val_loss: 0.0022 - val_mae: 0.0393 - val_mse: 0.0044 - val_rmse: 0.0663 - learning_rate: 1.0000e-04
# Epoch 28/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0032 - mae: 0.0474 - mse: 0.0064 - rmse: 0.0800 - val_loss: 0.0020 - val_mae: 0.0374 - val_mse: 0.0040 - val_rmse: 0.0631 - learning_rate: 1.0000e-04
# Epoch 29/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0031 - mae: 0.0467 - mse: 0.0062 - rmse: 0.0788 - val_loss: 0.0019 - val_mae: 0.0368 - val_mse: 0.0038 - val_rmse: 0.0617 - learning_rate: 1.0000e-04
# Epoch 30/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0030 - mae: 0.0462 - mse: 0.0061 - rmse: 0.0780 - val_loss: 0.0018 - val_mae: 0.0358 - val_mse: 0.0037 - val_rmse: 0.0607 - learning_rate: 1.0000e-04
# Epoch 31/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0029 - mae: 0.0458 - mse: 0.0060 - rmse: 0.0772 - val_loss: 0.0018 - val_mae: 0.0355 - val_mse: 0.0037 - val_rmse: 0.0610 - learning_rate: 1.0000e-04
# Epoch 32/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0029 - mae: 0.0452 - mse: 0.0058 - rmse: 0.0764 - val_loss: 0.0017 - val_mae: 0.0346 - val_mse: 0.0034 - val_rmse: 0.0585 - learning_rate: 1.0000e-04
# Epoch 33/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0028 - mae: 0.0450 - mse: 0.0058 - rmse: 0.0758 - val_loss: 0.0017 - val_mae: 0.0347 - val_mse: 0.0033 - val_rmse: 0.0577 - learning_rate: 1.0000e-04
# Epoch 34/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0028 - mae: 0.0446 - mse: 0.0057 - rmse: 0.0752 - val_loss: 0.0017 - val_mae: 0.0360 - val_mse: 0.0034 - val_rmse: 0.0586 - learning_rate: 1.0000e-04
# Epoch 35/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0028 - mae: 0.0442 - mse: 0.0056 - rmse: 0.0748 - val_loss: 0.0018 - val_mae: 0.0364 - val_mse: 0.0037 - val_rmse: 0.0609 - learning_rate: 1.0000e-04
# Epoch 36/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0027 - mae: 0.0439 - mse: 0.0055 - rmse: 0.0740 - val_loss: 0.0017 - val_mae: 0.0348 - val_mse: 0.0034 - val_rmse: 0.0584 - learning_rate: 1.0000e-04
# Epoch 37/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0027 - mae: 0.0439 - mse: 0.0055 - rmse: 0.0740 - val_loss: 0.0016 - val_mae: 0.0339 - val_mse: 0.0032 - val_rmse: 0.0565 - learning_rate: 1.0000e-04
# Epoch 38/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0026 - mae: 0.0430 - mse: 0.0053 - rmse: 0.0729 - val_loss: 0.0015 - val_mae: 0.0329 - val_mse: 0.0030 - val_rmse: 0.0550 - learning_rate: 1.0000e-04
# Epoch 39/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0026 - mae: 0.0430 - mse: 0.0053 - rmse: 0.0726 - val_loss: 0.0016 - val_mae: 0.0339 - val_mse: 0.0033 - val_rmse: 0.0572 - learning_rate: 1.0000e-04
# Epoch 40/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0026 - mae: 0.0425 - mse: 0.0052 - rmse: 0.0718 - val_loss: 0.0016 - val_mae: 0.0339 - val_mse: 0.0033 - val_rmse: 0.0574 - learning_rate: 1.0000e-04
# Epoch 41/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0025 - mae: 0.0421 - mse: 0.0051 - rmse: 0.0711 - val_loss: 0.0014 - val_mae: 0.0322 - val_mse: 0.0029 - val_rmse: 0.0537 - learning_rate: 1.0000e-04
# Epoch 42/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0025 - mae: 0.0422 - mse: 0.0051 - rmse: 0.0712 - val_loss: 0.0016 - val_mae: 0.0337 - val_mse: 0.0033 - val_rmse: 0.0576 - learning_rate: 1.0000e-04
# Epoch 43/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0025 - mae: 0.0420 - mse: 0.0051 - rmse: 0.0711 - val_loss: 0.0014 - val_mae: 0.0316 - val_mse: 0.0028 - val_rmse: 0.0530 - learning_rate: 1.0000e-04
# Epoch 44/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0024 - mae: 0.0414 - mse: 0.0049 - rmse: 0.0700 - val_loss: 0.0014 - val_mae: 0.0323 - val_mse: 0.0029 - val_rmse: 0.0534 - learning_rate: 1.0000e-04
# Epoch 45/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0024 - mae: 0.0413 - mse: 0.0049 - rmse: 0.0697 - val_loss: 0.0014 - val_mae: 0.0322 - val_mse: 0.0029 - val_rmse: 0.0538 - learning_rate: 1.0000e-04
# Epoch 46/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0024 - mae: 0.0411 - mse: 0.0048 - rmse: 0.0696 - val_loss: 0.0014 - val_mae: 0.0329 - val_mse: 0.0029 - val_rmse: 0.0538 - learning_rate: 1.0000e-04
# Epoch 47/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0023 - mae: 0.0404 - mse: 0.0046 - rmse: 0.0680 - val_loss: 0.0013 - val_mae: 0.0297 - val_mse: 0.0025 - val_rmse: 0.0502 - learning_rate: 5.0000e-05
# Epoch 48/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0022 - mae: 0.0399 - mse: 0.0045 - rmse: 0.0672 - val_loss: 0.0012 - val_mae: 0.0299 - val_mse: 0.0025 - val_rmse: 0.0495 - learning_rate: 5.0000e-05
# Epoch 49/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0022 - mae: 0.0398 - mse: 0.0045 - rmse: 0.0671 - val_loss: 0.0012 - val_mae: 0.0297 - val_mse: 0.0025 - val_rmse: 0.0496 - learning_rate: 5.0000e-05
# Epoch 50/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0022 - mae: 0.0396 - mse: 0.0044 - rmse: 0.0667 - val_loss: 0.0012 - val_mae: 0.0302 - val_mse: 0.0025 - val_rmse: 0.0501 - learning_rate: 5.0000e-05
# Epoch 51/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0022 - mae: 0.0394 - mse: 0.0044 - rmse: 0.0662 - val_loss: 0.0013 - val_mae: 0.0300 - val_mse: 0.0025 - val_rmse: 0.0504 - learning_rate: 5.0000e-05
# Epoch 52/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0022 - mae: 0.0393 - mse: 0.0044 - rmse: 0.0663 - val_loss: 0.0012 - val_mae: 0.0291 - val_mse: 0.0024 - val_rmse: 0.0488 - learning_rate: 5.0000e-05
# Epoch 53/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0021 - mae: 0.0391 - mse: 0.0043 - rmse: 0.0657 - val_loss: 0.0011 - val_mae: 0.0286 - val_mse: 0.0023 - val_rmse: 0.0477 - learning_rate: 2.5000e-05
# Epoch 54/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0021 - mae: 0.0388 - mse: 0.0043 - rmse: 0.0653 - val_loss: 0.0011 - val_mae: 0.0285 - val_mse: 0.0023 - val_rmse: 0.0476 - learning_rate: 2.5000e-05
# Epoch 55/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0021 - mae: 0.0386 - mse: 0.0042 - rmse: 0.0649 - val_loss: 0.0011 - val_mae: 0.0286 - val_mse: 0.0023 - val_rmse: 0.0479 - learning_rate: 2.5000e-05
# Epoch 56/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0021 - mae: 0.0385 - mse: 0.0042 - rmse: 0.0648 - val_loss: 0.0011 - val_mae: 0.0284 - val_mse: 0.0022 - val_rmse: 0.0474 - learning_rate: 2.5000e-05
# Epoch 57/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0021 - mae: 0.0385 - mse: 0.0042 - rmse: 0.0647 - val_loss: 0.0011 - val_mae: 0.0283 - val_mse: 0.0022 - val_rmse: 0.0473 - learning_rate: 2.5000e-05
# Epoch 58/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0021 - mae: 0.0386 - mse: 0.0042 - rmse: 0.0651 - val_loss: 0.0011 - val_mae: 0.0285 - val_mse: 0.0023 - val_rmse: 0.0477 - learning_rate: 2.5000e-05
# Epoch 59/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0021 - mae: 0.0382 - mse: 0.0041 - rmse: 0.0643 - val_loss: 0.0011 - val_mae: 0.0280 - val_mse: 0.0022 - val_rmse: 0.0469 - learning_rate: 1.2500e-05
# Epoch 60/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0021 - mae: 0.0384 - mse: 0.0042 - rmse: 0.0645 - val_loss: 0.0011 - val_mae: 0.0280 - val_mse: 0.0022 - val_rmse: 0.0468 - learning_rate: 1.2500e-05
# Epoch 61/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0020 - mae: 0.0382 - mse: 0.0041 - rmse: 0.0642 - val_loss: 0.0011 - val_mae: 0.0280 - val_mse: 0.0022 - val_rmse: 0.0467 - learning_rate: 1.2500e-05
# Epoch 62/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0020 - mae: 0.0379 - mse: 0.0041 - rmse: 0.0638 - val_loss: 0.0011 - val_mae: 0.0280 - val_mse: 0.0022 - val_rmse: 0.0465 - learning_rate: 1.2500e-05
# Epoch 63/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0020 - mae: 0.0381 - mse: 0.0041 - rmse: 0.0641 - val_loss: 0.0011 - val_mae: 0.0279 - val_mse: 0.0022 - val_rmse: 0.0464 - learning_rate: 1.2500e-05
# Epoch 64/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0020 - mae: 0.0380 - mse: 0.0041 - rmse: 0.0639 - val_loss: 0.0011 - val_mae: 0.0278 - val_mse: 0.0022 - val_rmse: 0.0465 - learning_rate: 6.2500e-06
# Epoch 65/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0020 - mae: 0.0379 - mse: 0.0041 - rmse: 0.0637 - val_loss: 0.0011 - val_mae: 0.0278 - val_mse: 0.0021 - val_rmse: 0.0464 - learning_rate: 6.2500e-06
# Epoch 66/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0020 - mae: 0.0379 - mse: 0.0041 - rmse: 0.0637 - val_loss: 0.0011 - val_mae: 0.0278 - val_mse: 0.0021 - val_rmse: 0.0462 - learning_rate: 6.2500e-06
# Epoch 67/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0020 - mae: 0.0378 - mse: 0.0040 - rmse: 0.0636 - val_loss: 0.0011 - val_mae: 0.0278 - val_mse: 0.0021 - val_rmse: 0.0462 - learning_rate: 6.2500e-06
# Epoch 68/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0020 - mae: 0.0377 - mse: 0.0040 - rmse: 0.0635 - val_loss: 0.0011 - val_mae: 0.0277 - val_mse: 0.0021 - val_rmse: 0.0462 - learning_rate: 6.2500e-06
# Epoch 69/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0020 - mae: 0.0377 - mse: 0.0040 - rmse: 0.0634 - val_loss: 0.0011 - val_mae: 0.0276 - val_mse: 0.0021 - val_rmse: 0.0462 - learning_rate: 3.1250e-06
# Epoch 70/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0020 - mae: 0.0377 - mse: 0.0040 - rmse: 0.0634 - val_loss: 0.0011 - val_mae: 0.0276 - val_mse: 0.0021 - val_rmse: 0.0460 - learning_rate: 3.1250e-06
# Epoch 71/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0020 - mae: 0.0378 - mse: 0.0040 - rmse: 0.0636 - val_loss: 0.0011 - val_mae: 0.0277 - val_mse: 0.0021 - val_rmse: 0.0460 - learning_rate: 3.1250e-06
# Epoch 72/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0020 - mae: 0.0377 - mse: 0.0040 - rmse: 0.0635 - val_loss: 0.0011 - val_mae: 0.0276 - val_mse: 0.0021 - val_rmse: 0.0461 - learning_rate: 3.1250e-06
# Epoch 73/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0020 - mae: 0.0377 - mse: 0.0040 - rmse: 0.0634 - val_loss: 0.0011 - val_mae: 0.0277 - val_mse: 0.0021 - val_rmse: 0.0461 - learning_rate: 3.1250e-06
# Epoch 74/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - loss: 0.0020 - mae: 0.0376 - mse: 0.0040 - rmse: 0.0634 - val_loss: 0.0011 - val_mae: 0.0275 - val_mse: 0.0021 - val_rmse: 0.0461 - learning_rate: 1.5625e-06
# Epoch 75/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0020 - mae: 0.0376 - mse: 0.0040 - rmse: 0.0632 - val_loss: 0.0011 - val_mae: 0.0276 - val_mse: 0.0021 - val_rmse: 0.0461 - learning_rate: 1.5625e-06
# Epoch 76/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0020 - mae: 0.0377 - mse: 0.0040 - rmse: 0.0635 - val_loss: 0.0011 - val_mae: 0.0276 - val_mse: 0.0021 - val_rmse: 0.0460 - learning_rate: 1.5625e-06
# Epoch 77/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0020 - mae: 0.0377 - mse: 0.0040 - rmse: 0.0634 - val_loss: 0.0011 - val_mae: 0.0275 - val_mse: 0.0021 - val_rmse: 0.0460 - learning_rate: 1.5625e-06
# Epoch 78/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0020 - mae: 0.0377 - mse: 0.0040 - rmse: 0.0635 - val_loss: 0.0011 - val_mae: 0.0275 - val_mse: 0.0021 - val_rmse: 0.0459 - learning_rate: 1.5625e-06
# Epoch 79/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0020 - mae: 0.0376 - mse: 0.0040 - rmse: 0.0633 - val_loss: 0.0011 - val_mae: 0.0276 - val_mse: 0.0021 - val_rmse: 0.0459 - learning_rate: 7.8125e-07
# Epoch 80/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 53s 15ms/step - loss: 0.0020 - mae: 0.0375 - mse: 0.0040 - rmse: 0.0629 - val_loss: 0.0011 - val_mae: 0.0276 - val_mse: 0.0021 - val_rmse: 0.0460 - learning_rate: 7.8125e-07

# %%
plt.figure(figsize=(20, 10))
# Plot the training and validation loss
plt.subplot(2, 2, 1)
plt.plot(saliency_model.history['loss'][0:])
plt.plot(saliency_model.history['val_loss'][0:])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(2, 2, 2)
plt.plot(saliency_model.history['mse'][0:])
plt.plot(saliency_model.history['val_mse'][0:])
plt.title('Model MSE')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(2, 2, 3)
plt.plot(saliency_model.history['mae'][0:])
plt.plot(saliency_model.history['val_mae'][0:])
plt.title('Model MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(2, 2, 4)
plt.plot(saliency_model.history['rmse'][0:])
plt.plot(saliency_model.history['val_rmse'][0:])
plt.title('Model RMSE')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
model.save('../saved-models/new-model-64.h5')

# %%
import gc
del X_train 
del y_train
gc.collect()
# Out:
# 16612

# %%
# evaluate model
X_test = np.concatenate([np.load(f).astype(np.uint8) for f in val_files])
y_test = np.concatenate([np.loadtxt(f"../3d-meshes/{os.path.basename(f).replace('.npy', '.txt')}").astype(np.float32) for f in val_files])
loss, mse, mae, rmse = model.evaluate(X_test, y_test, verbose=1)
print("Loss: ", loss)
print("MSE: ", mse)
print("MAE: ", mae)
print("RMSE: ", rmse)
# Out:
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.0066 - mae: 0.0608 - mse: 0.0135 - rmse: 0.1152
# Loss:  0.007526360917836428
# MSE:  0.015403098426759243
# MAE:  0.07049744576215744
# RMSE:  0.12410835176706314
