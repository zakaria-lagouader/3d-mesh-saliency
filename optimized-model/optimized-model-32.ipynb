# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.losses import Huber
from keras.regularizers import l2
from keras.metrics import MeanSquaredError, MeanAbsoluteError,RootMeanSquaredError
from keras import Sequential, layers
from keras.optimizers import Adam
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
# Out:
# 2024-08-17 21:39:16.992234: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-17 21:39:16.992363: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-17 21:39:17.115861: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Hyper parameters
PATCH_SIZE = 32
BATCH_SIZE = 200
EPOCHS = 80
DROPOUT_RATE = 0.5
L2_RATE = 1e-3

# %%
val_files = {
    "../patches-32/skull_decimated.npy", 
    "../patches-32/ant_decimated.npy", 
    "../patches-32/vase_decimated.npy", 
    "../patches-32/isis_decimated.npy", 
    "../patches-32/teddy_decimated.npy",
    "../patches-32/teapot_decimated.npy"
}

patche_files = sorted(glob.glob('../patches-32/*.npy'))
patche_files = list(set(patche_files) - val_files)
saliency_files = [
    f"../3d-meshes/{os.path.basename(f).replace('.npy', '.txt')}" 
    for f in patche_files
]

print('Number of patches:', len(patche_files))
print('Number of saliency maps:', len(saliency_files))
# Out:
# Number of patches: 43
# Number of saliency maps: 43

# %%
X_train = np.concatenate([np.load(f, mmap_mode="r").astype(np.float32) for f in patche_files])
y_train = np.concatenate([np.loadtxt(f).astype(np.float32) for f in saliency_files])
    
X_train, y_train = shuffle(X_train, y_train)
X_train.shape, y_train.shape, X_train.dtype, y_train.dtype
# Out:
# ((859999, 32, 32, 3), (859999,), dtype('float32'), dtype('float32'))

# %%
# Define the CNN model
model = Sequential()

# Convolutional layers with L2 regularization
model.add(layers.Conv2D(32, (3, 3), padding="same", strides=(1, 1), activation="relu",
                        kernel_regularizer=l2(L2_RATE), input_shape=(PATCH_SIZE, PATCH_SIZE, 3)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), padding="valid"))

model.add(layers.Conv2D(64, (3, 3), padding="same", strides=(1, 1), activation='relu',
                       kernel_regularizer=l2(L2_RATE)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), padding="valid"))

model.add(layers.Conv2D(128, (3, 3), padding="same", strides=(1, 1), activation='relu',
                       kernel_regularizer=l2(L2_RATE)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), padding="valid"))

# Flatten the output from convolutional layers
model.add(layers.Flatten())

# Dense layers with L2 regularization
model.add(layers.Dense(256, activation='relu', kernel_regularizer=l2(L2_RATE)))
model.add(layers.Dropout(DROPOUT_RATE))
model.add(layers.Dense(256, activation='relu', kernel_regularizer=l2(L2_RATE)))
model.add(layers.Dropout(DROPOUT_RATE))

# Output layer
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss=Huber(),
              metrics=[
                  MeanSquaredError(name='mse'),
                  MeanAbsoluteError(name='mae'),
                  RootMeanSquaredError(name='rmse'),
              ])

# Print the model summary
model.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 684,737 (2.61 MB)
#  Trainable params: 684,289 (2.61 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# fit the model
saliency_model = model.fit(
    X_train, y_train, 
    batch_size=BATCH_SIZE, 
    epochs=EPOCHS, 
    validation_split=0.2, 
    verbose=1,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/80
#   10/3440 ━━━━━━━━━━━━━━━━━━━━ 43s 13ms/step - loss: 0.9038 - mae: 0.2170 - mse: 0.1194 - rmse: 0.3407
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1723930945.773563      82 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1723930945.799660      82 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2867 - mae: 0.0972 - mse: 0.0314 - rmse: 0.1767
# W0000 00:00:1723930981.769358      82 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1723930987.526299      81 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 55s 13ms/step - loss: 0.2867 - mae: 0.0972 - mse: 0.0314 - rmse: 0.1767 - val_loss: 0.0143 - val_mae: 0.0868 - val_mse: 0.0239 - val_rmse: 0.1546 - learning_rate: 1.0000e-04
# Epoch 2/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0138 - mae: 0.0910 - mse: 0.0235 - rmse: 0.1532 - val_loss: 0.0132 - val_mae: 0.0956 - val_mse: 0.0229 - val_rmse: 0.1514 - learning_rate: 1.0000e-04
# Epoch 3/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0128 - mae: 0.0881 - mse: 0.0222 - rmse: 0.1489 - val_loss: 0.0127 - val_mae: 0.0881 - val_mse: 0.0220 - val_rmse: 0.1484 - learning_rate: 1.0000e-04
# Epoch 4/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0123 - mae: 0.0853 - mse: 0.0211 - rmse: 0.1453 - val_loss: 0.0121 - val_mae: 0.0917 - val_mse: 0.0207 - val_rmse: 0.1437 - learning_rate: 1.0000e-04
# Epoch 5/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0120 - mae: 0.0833 - mse: 0.0202 - rmse: 0.1422 - val_loss: 0.0131 - val_mae: 0.0843 - val_mse: 0.0223 - val_rmse: 0.1494 - learning_rate: 1.0000e-04
# Epoch 6/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0116 - mae: 0.0815 - mse: 0.0195 - rmse: 0.1395 - val_loss: 0.0117 - val_mae: 0.0869 - val_mse: 0.0195 - val_rmse: 0.1398 - learning_rate: 1.0000e-04
# Epoch 7/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0114 - mae: 0.0804 - mse: 0.0190 - rmse: 0.1377 - val_loss: 0.0118 - val_mae: 0.0812 - val_mse: 0.0197 - val_rmse: 0.1403 - learning_rate: 1.0000e-04
# Epoch 8/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0113 - mae: 0.0794 - mse: 0.0186 - rmse: 0.1363 - val_loss: 0.0124 - val_mae: 0.0911 - val_mse: 0.0209 - val_rmse: 0.1444 - learning_rate: 1.0000e-04
# Epoch 9/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0112 - mae: 0.0787 - mse: 0.0182 - rmse: 0.1351 - val_loss: 0.0133 - val_mae: 0.0776 - val_mse: 0.0225 - val_rmse: 0.1501 - learning_rate: 1.0000e-04
# Epoch 10/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0110 - mae: 0.0780 - mse: 0.0180 - rmse: 0.1341 - val_loss: 0.0120 - val_mae: 0.0805 - val_mse: 0.0198 - val_rmse: 0.1408 - learning_rate: 1.0000e-04
# Epoch 11/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0110 - mae: 0.0777 - mse: 0.0178 - rmse: 0.1335 - val_loss: 0.0110 - val_mae: 0.0731 - val_mse: 0.0179 - val_rmse: 0.1337 - learning_rate: 1.0000e-04
# Epoch 12/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0109 - mae: 0.0773 - mse: 0.0176 - rmse: 0.1328 - val_loss: 0.0111 - val_mae: 0.0734 - val_mse: 0.0179 - val_rmse: 0.1339 - learning_rate: 1.0000e-04
# Epoch 13/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0108 - mae: 0.0763 - mse: 0.0173 - rmse: 0.1315 - val_loss: 0.0126 - val_mae: 0.0824 - val_mse: 0.0208 - val_rmse: 0.1444 - learning_rate: 1.0000e-04
# Epoch 14/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0107 - mae: 0.0762 - mse: 0.0172 - rmse: 0.1311 - val_loss: 0.0126 - val_mae: 0.0787 - val_mse: 0.0210 - val_rmse: 0.1450 - learning_rate: 1.0000e-04
# Epoch 15/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0107 - mae: 0.0759 - mse: 0.0170 - rmse: 0.1305 - val_loss: 0.0123 - val_mae: 0.0802 - val_mse: 0.0203 - val_rmse: 0.1426 - learning_rate: 1.0000e-04
# Epoch 16/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0105 - mae: 0.0751 - mse: 0.0167 - rmse: 0.1292 - val_loss: 0.0113 - val_mae: 0.0740 - val_mse: 0.0181 - val_rmse: 0.1346 - learning_rate: 1.0000e-04
# Epoch 17/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0098 - mae: 0.0724 - mse: 0.0154 - rmse: 0.1240 - val_loss: 0.0104 - val_mae: 0.0746 - val_mse: 0.0170 - val_rmse: 0.1303 - learning_rate: 5.0000e-05
# Epoch 18/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0092 - mae: 0.0706 - mse: 0.0145 - rmse: 0.1204 - val_loss: 0.0096 - val_mae: 0.0716 - val_mse: 0.0155 - val_rmse: 0.1243 - learning_rate: 5.0000e-05
# Epoch 19/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0090 - mae: 0.0699 - mse: 0.0142 - rmse: 0.1193 - val_loss: 0.0099 - val_mae: 0.0717 - val_mse: 0.0160 - val_rmse: 0.1264 - learning_rate: 5.0000e-05
# Epoch 20/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0089 - mae: 0.0690 - mse: 0.0139 - rmse: 0.1179 - val_loss: 0.0104 - val_mae: 0.0748 - val_mse: 0.0169 - val_rmse: 0.1300 - learning_rate: 5.0000e-05
# Epoch 21/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0088 - mae: 0.0687 - mse: 0.0138 - rmse: 0.1174 - val_loss: 0.0097 - val_mae: 0.0697 - val_mse: 0.0155 - val_rmse: 0.1246 - learning_rate: 5.0000e-05
# Epoch 22/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0087 - mae: 0.0681 - mse: 0.0136 - rmse: 0.1164 - val_loss: 0.0091 - val_mae: 0.0717 - val_mse: 0.0143 - val_rmse: 0.1196 - learning_rate: 5.0000e-05
# Epoch 23/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0086 - mae: 0.0678 - mse: 0.0134 - rmse: 0.1160 - val_loss: 0.0091 - val_mae: 0.0710 - val_mse: 0.0144 - val_rmse: 0.1201 - learning_rate: 5.0000e-05
# Epoch 24/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0086 - mae: 0.0676 - mse: 0.0133 - rmse: 0.1152 - val_loss: 0.0102 - val_mae: 0.0772 - val_mse: 0.0165 - val_rmse: 0.1286 - learning_rate: 5.0000e-05
# Epoch 25/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0086 - mae: 0.0673 - mse: 0.0132 - rmse: 0.1150 - val_loss: 0.0091 - val_mae: 0.0696 - val_mse: 0.0143 - val_rmse: 0.1196 - learning_rate: 5.0000e-05
# Epoch 26/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0085 - mae: 0.0670 - mse: 0.0131 - rmse: 0.1143 - val_loss: 0.0103 - val_mae: 0.0727 - val_mse: 0.0166 - val_rmse: 0.1287 - learning_rate: 5.0000e-05
# Epoch 27/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0085 - mae: 0.0667 - mse: 0.0130 - rmse: 0.1140 - val_loss: 0.0115 - val_mae: 0.0829 - val_mse: 0.0190 - val_rmse: 0.1379 - learning_rate: 5.0000e-05
# Epoch 28/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0079 - mae: 0.0642 - mse: 0.0119 - rmse: 0.1091 - val_loss: 0.0082 - val_mae: 0.0640 - val_mse: 0.0127 - val_rmse: 0.1129 - learning_rate: 2.5000e-05
# Epoch 29/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0075 - mae: 0.0631 - mse: 0.0114 - rmse: 0.1069 - val_loss: 0.0083 - val_mae: 0.0646 - val_mse: 0.0129 - val_rmse: 0.1136 - learning_rate: 2.5000e-05
# Epoch 30/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0074 - mae: 0.0627 - mse: 0.0112 - rmse: 0.1060 - val_loss: 0.0082 - val_mae: 0.0649 - val_mse: 0.0128 - val_rmse: 0.1131 - learning_rate: 2.5000e-05
# Epoch 31/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0074 - mae: 0.0625 - mse: 0.0111 - rmse: 0.1055 - val_loss: 0.0080 - val_mae: 0.0633 - val_mse: 0.0124 - val_rmse: 0.1114 - learning_rate: 2.5000e-05
# Epoch 32/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0073 - mae: 0.0623 - mse: 0.0110 - rmse: 0.1049 - val_loss: 0.0093 - val_mae: 0.0698 - val_mse: 0.0151 - val_rmse: 0.1227 - learning_rate: 2.5000e-05
# Epoch 33/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 41s 10ms/step - loss: 0.0072 - mae: 0.0620 - mse: 0.0109 - rmse: 0.1046 - val_loss: 0.0082 - val_mae: 0.0630 - val_mse: 0.0129 - val_rmse: 0.1135 - learning_rate: 2.5000e-05
# Epoch 34/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0072 - mae: 0.0617 - mse: 0.0108 - rmse: 0.1040 - val_loss: 0.0081 - val_mae: 0.0615 - val_mse: 0.0127 - val_rmse: 0.1125 - learning_rate: 2.5000e-05
# Epoch 35/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0072 - mae: 0.0615 - mse: 0.0108 - rmse: 0.1039 - val_loss: 0.0086 - val_mae: 0.0636 - val_mse: 0.0137 - val_rmse: 0.1168 - learning_rate: 2.5000e-05
# Epoch 36/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0071 - mae: 0.0616 - mse: 0.0108 - rmse: 0.1039 - val_loss: 0.0079 - val_mae: 0.0640 - val_mse: 0.0123 - val_rmse: 0.1111 - learning_rate: 2.5000e-05
# Epoch 37/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0068 - mae: 0.0601 - mse: 0.0101 - rmse: 0.1007 - val_loss: 0.0076 - val_mae: 0.0611 - val_mse: 0.0118 - val_rmse: 0.1087 - learning_rate: 1.2500e-05
# Epoch 38/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0066 - mae: 0.0592 - mse: 0.0098 - rmse: 0.0991 - val_loss: 0.0075 - val_mae: 0.0613 - val_mse: 0.0117 - val_rmse: 0.1082 - learning_rate: 1.2500e-05
# Epoch 39/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0065 - mae: 0.0590 - mse: 0.0097 - rmse: 0.0985 - val_loss: 0.0077 - val_mae: 0.0609 - val_mse: 0.0120 - val_rmse: 0.1095 - learning_rate: 1.2500e-05
# Epoch 40/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0065 - mae: 0.0590 - mse: 0.0097 - rmse: 0.0985 - val_loss: 0.0076 - val_mae: 0.0615 - val_mse: 0.0119 - val_rmse: 0.1090 - learning_rate: 1.2500e-05
# Epoch 41/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0065 - mae: 0.0587 - mse: 0.0096 - rmse: 0.0981 - val_loss: 0.0076 - val_mae: 0.0612 - val_mse: 0.0119 - val_rmse: 0.1091 - learning_rate: 1.2500e-05
# Epoch 42/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0065 - mae: 0.0587 - mse: 0.0096 - rmse: 0.0980 - val_loss: 0.0077 - val_mae: 0.0624 - val_mse: 0.0122 - val_rmse: 0.1104 - learning_rate: 1.2500e-05
# Epoch 43/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0063 - mae: 0.0579 - mse: 0.0093 - rmse: 0.0963 - val_loss: 0.0074 - val_mae: 0.0603 - val_mse: 0.0116 - val_rmse: 0.1076 - learning_rate: 6.2500e-06
# Epoch 44/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0062 - mae: 0.0573 - mse: 0.0091 - rmse: 0.0954 - val_loss: 0.0074 - val_mae: 0.0606 - val_mse: 0.0115 - val_rmse: 0.1074 - learning_rate: 6.2500e-06
# Epoch 45/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0062 - mae: 0.0573 - mse: 0.0091 - rmse: 0.0953 - val_loss: 0.0075 - val_mae: 0.0609 - val_mse: 0.0117 - val_rmse: 0.1082 - learning_rate: 6.2500e-06
# Epoch 46/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0061 - mae: 0.0571 - mse: 0.0090 - rmse: 0.0951 - val_loss: 0.0074 - val_mae: 0.0611 - val_mse: 0.0116 - val_rmse: 0.1075 - learning_rate: 6.2500e-06
# Epoch 47/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0061 - mae: 0.0572 - mse: 0.0090 - rmse: 0.0949 - val_loss: 0.0074 - val_mae: 0.0603 - val_mse: 0.0116 - val_rmse: 0.1077 - learning_rate: 6.2500e-06
# Epoch 48/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0061 - mae: 0.0567 - mse: 0.0089 - rmse: 0.0943 - val_loss: 0.0074 - val_mae: 0.0608 - val_mse: 0.0117 - val_rmse: 0.1081 - learning_rate: 6.2500e-06
# Epoch 49/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0060 - mae: 0.0565 - mse: 0.0087 - rmse: 0.0935 - val_loss: 0.0073 - val_mae: 0.0603 - val_mse: 0.0115 - val_rmse: 0.1070 - learning_rate: 3.1250e-06
# Epoch 50/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0059 - mae: 0.0563 - mse: 0.0087 - rmse: 0.0931 - val_loss: 0.0073 - val_mae: 0.0601 - val_mse: 0.0114 - val_rmse: 0.1068 - learning_rate: 3.1250e-06
# Epoch 51/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0060 - mae: 0.0565 - mse: 0.0087 - rmse: 0.0934 - val_loss: 0.0073 - val_mae: 0.0604 - val_mse: 0.0115 - val_rmse: 0.1071 - learning_rate: 3.1250e-06
# Epoch 52/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0059 - mae: 0.0561 - mse: 0.0087 - rmse: 0.0931 - val_loss: 0.0074 - val_mae: 0.0607 - val_mse: 0.0116 - val_rmse: 0.1078 - learning_rate: 3.1250e-06
# Epoch 53/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.0059 - mae: 0.0562 - mse: 0.0087 - rmse: 0.0931 - val_loss: 0.0074 - val_mae: 0.0593 - val_mse: 0.0116 - val_rmse: 0.1075 - learning_rate: 3.1250e-06
# Epoch 54/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0059 - mae: 0.0562 - mse: 0.0087 - rmse: 0.0932 - val_loss: 0.0073 - val_mae: 0.0601 - val_mse: 0.0115 - val_rmse: 0.1072 - learning_rate: 3.1250e-06
# Epoch 55/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0558 - mse: 0.0085 - rmse: 0.0922 - val_loss: 0.0073 - val_mae: 0.0596 - val_mse: 0.0114 - val_rmse: 0.1069 - learning_rate: 1.5625e-06
# Epoch 56/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0557 - mse: 0.0085 - rmse: 0.0923 - val_loss: 0.0073 - val_mae: 0.0605 - val_mse: 0.0114 - val_rmse: 0.1069 - learning_rate: 1.5625e-06
# Epoch 57/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0558 - mse: 0.0085 - rmse: 0.0923 - val_loss: 0.0073 - val_mae: 0.0603 - val_mse: 0.0115 - val_rmse: 0.1070 - learning_rate: 1.5625e-06
# Epoch 58/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0556 - mse: 0.0084 - rmse: 0.0919 - val_loss: 0.0073 - val_mae: 0.0601 - val_mse: 0.0114 - val_rmse: 0.1069 - learning_rate: 1.5625e-06
# Epoch 59/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0556 - mse: 0.0085 - rmse: 0.0921 - val_loss: 0.0073 - val_mae: 0.0600 - val_mse: 0.0114 - val_rmse: 0.1069 - learning_rate: 1.5625e-06
# Epoch 60/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 41s 10ms/step - loss: 0.0058 - mae: 0.0556 - mse: 0.0084 - rmse: 0.0919 - val_loss: 0.0073 - val_mae: 0.0597 - val_mse: 0.0114 - val_rmse: 0.1069 - learning_rate: 7.8125e-07
# Epoch 61/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0555 - mse: 0.0084 - rmse: 0.0918 - val_loss: 0.0073 - val_mae: 0.0602 - val_mse: 0.0114 - val_rmse: 0.1068 - learning_rate: 7.8125e-07
# Epoch 62/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0555 - mse: 0.0084 - rmse: 0.0916 - val_loss: 0.0073 - val_mae: 0.0601 - val_mse: 0.0114 - val_rmse: 0.1068 - learning_rate: 7.8125e-07
# Epoch 63/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0557 - mse: 0.0084 - rmse: 0.0919 - val_loss: 0.0073 - val_mae: 0.0601 - val_mse: 0.0114 - val_rmse: 0.1067 - learning_rate: 7.8125e-07
# Epoch 64/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0555 - mse: 0.0084 - rmse: 0.0917 - val_loss: 0.0073 - val_mae: 0.0598 - val_mse: 0.0114 - val_rmse: 0.1069 - learning_rate: 7.8125e-07
# Epoch 65/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0554 - mse: 0.0084 - rmse: 0.0916 - val_loss: 0.0073 - val_mae: 0.0601 - val_mse: 0.0114 - val_rmse: 0.1068 - learning_rate: 3.9062e-07
# Epoch 66/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0556 - mse: 0.0084 - rmse: 0.0918 - val_loss: 0.0073 - val_mae: 0.0599 - val_mse: 0.0114 - val_rmse: 0.1068 - learning_rate: 3.9062e-07
# Epoch 67/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.0058 - mae: 0.0555 - mse: 0.0084 - rmse: 0.0917 - val_loss: 0.0073 - val_mae: 0.0598 - val_mse: 0.0114 - val_rmse: 0.1068 - learning_rate: 3.9062e-07
# Epoch 68/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0554 - mse: 0.0084 - rmse: 0.0915 - val_loss: 0.0073 - val_mae: 0.0599 - val_mse: 0.0114 - val_rmse: 0.1069 - learning_rate: 3.9062e-07
# Epoch 69/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0554 - mse: 0.0084 - rmse: 0.0915 - val_loss: 0.0073 - val_mae: 0.0599 - val_mse: 0.0114 - val_rmse: 0.1068 - learning_rate: 3.9062e-07
# Epoch 70/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.0057 - mae: 0.0554 - mse: 0.0084 - rmse: 0.0914 - val_loss: 0.0073 - val_mae: 0.0600 - val_mse: 0.0114 - val_rmse: 0.1069 - learning_rate: 1.9531e-07
# Epoch 71/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0057 - mae: 0.0554 - mse: 0.0083 - rmse: 0.0914 - val_loss: 0.0073 - val_mae: 0.0598 - val_mse: 0.0114 - val_rmse: 0.1069 - learning_rate: 1.9531e-07
# Epoch 72/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0058 - mae: 0.0555 - mse: 0.0084 - rmse: 0.0917 - val_loss: 0.0073 - val_mae: 0.0599 - val_mse: 0.0114 - val_rmse: 0.1069 - learning_rate: 1.9531e-07
# Epoch 73/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 0.0057 - mae: 0.0553 - mse: 0.0084 - rmse: 0.0914 - val_loss: 0.0073 - val_mae: 0.0598 - val_mse: 0.0114 - val_rmse: 0.1069 - learning_rate: 1.9531e-07

# %%
plt.figure(figsize=(20, 10))
# Plot the training and validation loss
plt.subplot(2, 2, 1)
plt.plot(saliency_model.history['loss'][0:])
plt.plot(saliency_model.history['val_loss'][0:])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(2, 2, 2)
plt.plot(saliency_model.history['mse'][0:])
plt.plot(saliency_model.history['val_mse'][0:])
plt.title('Model MSE')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(2, 2, 3)
plt.plot(saliency_model.history['mae'][0:])
plt.plot(saliency_model.history['val_mae'][0:])
plt.title('Model MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(2, 2, 4)
plt.plot(saliency_model.history['rmse'][0:])
plt.plot(saliency_model.history['val_rmse'][0:])
plt.title('Model RMSE')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
model.save('../saved-models/optimized-model-32.h5')

# %%
import gc
del X_train 
del y_train
gc.collect()
# Out:
# 16334

# %%
# evaluate model
X_test = np.concatenate([np.load(f).astype(np.float32) for f in val_files])
y_test = np.concatenate([np.loadtxt(f"../3d-meshes/{os.path.basename(f).replace('.npy', '.txt')}").astype(np.float32) for f in val_files])
loss, mse, mae, rmse = model.evaluate(X_test, y_test, verbose=1)
print("Loss: ", loss)
print("MSE: ", mse)
print("MAE: ", mae)
print("RMSE: ", rmse)
# Out:
#   78/3750 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.0154 - mae: 0.0921 - mse: 0.0277 - rmse: 0.1664
# W0000 00:00:1723933425.467934      80 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0137 - mae: 0.0908 - mse: 0.0243 - rmse: 0.1556
# Loss:  0.01169496402144432
# MSE:  0.020250171422958374
# MAE:  0.0794220119714737
# RMSE:  0.14230309426784515
