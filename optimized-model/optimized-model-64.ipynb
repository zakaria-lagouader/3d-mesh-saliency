# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.losses import Huber
from keras.regularizers import l2
from keras.metrics import MeanSquaredError, MeanAbsoluteError,RootMeanSquaredError
from keras import Sequential, layers
from keras.optimizers import Adam
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
# Out:
# 2024-08-17 22:34:35.859572: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-17 22:34:35.859704: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-17 22:34:36.006280: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Hyper parameters
PATCH_SIZE = 64
BATCH_SIZE = 200
EPOCHS = 80
DROPOUT_RATE = 0.5
L2_RATE = 1e-3

# %%
val_files = {
    "../patches-64/skull_decimated.npy", 
    "../patches-64/ant_decimated.npy", 
    "../patches-64/vase_decimated.npy", 
    "../patches-64/isis_decimated.npy", 
    "../patches-64/teddy_decimated.npy",
    "../patches-64/teapot_decimated.npy"
}

patche_files = sorted(glob.glob('../patches-64/*.npy'))
patche_files = list(set(patche_files) - val_files)
saliency_files = [
    f"../3d-meshes/{os.path.basename(f).replace('.npy', '.txt')}" 
    for f in patche_files
]

print('Number of patches:', len(patche_files))
print('Number of saliency maps:', len(saliency_files))
# Out:
# Number of patches: 43
# Number of saliency maps: 43

# %%
X_train = np.concatenate([np.load(f, mmap_mode="r").astype(np.uint8) for f in patche_files])
y_train = np.concatenate([np.loadtxt(f).astype(np.float32) for f in saliency_files])
    
X_train, y_train = shuffle(X_train, y_train)
X_train.shape, y_train.shape, X_train.dtype, y_train.dtype
# Out:
# ((859999, 64, 64, 3), (859999,), dtype('uint8'), dtype('float32'))

# %%
# Define the CNN model
model = Sequential()

# Convolutional layers with L2 regularization
model.add(layers.Conv2D(32, (3, 3), padding="same", strides=(1, 1), activation="relu",
                        kernel_regularizer=l2(L2_RATE), input_shape=(PATCH_SIZE, PATCH_SIZE, 3)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), padding="valid"))

model.add(layers.Conv2D(64, (3, 3), padding="same", strides=(1, 1), activation='relu',
                       kernel_regularizer=l2(L2_RATE)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), padding="valid"))

model.add(layers.Conv2D(128, (3, 3), padding="same", strides=(1, 1), activation='relu',
                       kernel_regularizer=l2(L2_RATE)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), padding="valid"))

# Flatten the output from convolutional layers
model.add(layers.Flatten())

# Dense layers with L2 regularization
model.add(layers.Dense(256, activation='relu', kernel_regularizer=l2(L2_RATE)))
model.add(layers.Dropout(DROPOUT_RATE))
model.add(layers.Dense(256, activation='relu', kernel_regularizer=l2(L2_RATE)))
model.add(layers.Dropout(DROPOUT_RATE))

# Output layer
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss=Huber(),
              metrics=[
                  MeanSquaredError(name='mse'),
                  MeanAbsoluteError(name='mae'),
                  RootMeanSquaredError(name='rmse'),
              ])

# Print the model summary
model.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 64, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,097,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,257,601 (8.61 MB)
#  Trainable params: 2,257,153 (8.61 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# fit the model
saliency_model = model.fit(
    X_train, y_train, 
    batch_size=BATCH_SIZE, 
    epochs=EPOCHS, 
    validation_split=0.2, 
    verbose=1,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/80
#    4/3440 ━━━━━━━━━━━━━━━━━━━━ 2:24 42ms/step - loss: 0.9965 - mae: 0.3384 - mse: 0.2214 - rmse: 0.4633
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1723934248.853701      84 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1723934248.880306      84 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2756 - mae: 0.0927 - mse: 0.0311 - rmse: 0.1754
# W0000 00:00:1723934347.417350      83 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1723934353.259376      83 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 123s 32ms/step - loss: 0.2756 - mae: 0.0927 - mse: 0.0311 - rmse: 0.1754 - val_loss: 0.0130 - val_mae: 0.0747 - val_mse: 0.0164 - val_rmse: 0.1283 - learning_rate: 1.0000e-04
# Epoch 2/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 98s 29ms/step - loss: 0.0124 - mae: 0.0757 - mse: 0.0161 - rmse: 0.1269 - val_loss: 0.0121 - val_mae: 0.0664 - val_mse: 0.0167 - val_rmse: 0.1293 - learning_rate: 1.0000e-04
# Epoch 3/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 98s 28ms/step - loss: 0.0104 - mae: 0.0685 - mse: 0.0132 - rmse: 0.1148 - val_loss: 0.0102 - val_mae: 0.0639 - val_mse: 0.0132 - val_rmse: 0.1148 - learning_rate: 1.0000e-04
# Epoch 4/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 98s 28ms/step - loss: 0.0093 - mae: 0.0648 - mse: 0.0115 - rmse: 0.1073 - val_loss: 0.0088 - val_mae: 0.0614 - val_mse: 0.0107 - val_rmse: 0.1036 - learning_rate: 1.0000e-04
# Epoch 5/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 98s 28ms/step - loss: 0.0089 - mae: 0.0631 - mse: 0.0109 - rmse: 0.1044 - val_loss: 0.0096 - val_mae: 0.0600 - val_mse: 0.0123 - val_rmse: 0.1110 - learning_rate: 1.0000e-04
# Epoch 6/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0085 - mae: 0.0617 - mse: 0.0104 - rmse: 0.1021 - val_loss: 0.0094 - val_mae: 0.0660 - val_mse: 0.0123 - val_rmse: 0.1108 - learning_rate: 1.0000e-04
# Epoch 7/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 98s 28ms/step - loss: 0.0083 - mae: 0.0611 - mse: 0.0102 - rmse: 0.1010 - val_loss: 0.0088 - val_mae: 0.0631 - val_mse: 0.0112 - val_rmse: 0.1056 - learning_rate: 1.0000e-04
# Epoch 8/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 142s 28ms/step - loss: 0.0082 - mae: 0.0604 - mse: 0.0100 - rmse: 0.0999 - val_loss: 0.0088 - val_mae: 0.0629 - val_mse: 0.0111 - val_rmse: 0.1054 - learning_rate: 1.0000e-04
# Epoch 9/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 98s 28ms/step - loss: 0.0080 - mae: 0.0596 - mse: 0.0097 - rmse: 0.0984 - val_loss: 0.0084 - val_mae: 0.0649 - val_mse: 0.0107 - val_rmse: 0.1033 - learning_rate: 1.0000e-04
# Epoch 10/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 98s 28ms/step - loss: 0.0079 - mae: 0.0589 - mse: 0.0095 - rmse: 0.0976 - val_loss: 0.0084 - val_mae: 0.0613 - val_mse: 0.0106 - val_rmse: 0.1029 - learning_rate: 1.0000e-04
# Epoch 11/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 98s 28ms/step - loss: 0.0078 - mae: 0.0586 - mse: 0.0094 - rmse: 0.0971 - val_loss: 0.0083 - val_mae: 0.0668 - val_mse: 0.0107 - val_rmse: 0.1035 - learning_rate: 1.0000e-04
# Epoch 12/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0078 - mae: 0.0584 - mse: 0.0094 - rmse: 0.0971 - val_loss: 0.0080 - val_mae: 0.0591 - val_mse: 0.0099 - val_rmse: 0.0996 - learning_rate: 1.0000e-04
# Epoch 13/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 98s 28ms/step - loss: 0.0076 - mae: 0.0578 - mse: 0.0092 - rmse: 0.0959 - val_loss: 0.0087 - val_mae: 0.0623 - val_mse: 0.0113 - val_rmse: 0.1063 - learning_rate: 1.0000e-04
# Epoch 14/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0075 - mae: 0.0574 - mse: 0.0090 - rmse: 0.0949 - val_loss: 0.0077 - val_mae: 0.0568 - val_mse: 0.0092 - val_rmse: 0.0960 - learning_rate: 1.0000e-04
# Epoch 15/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0075 - mae: 0.0575 - mse: 0.0091 - rmse: 0.0952 - val_loss: 0.0100 - val_mae: 0.0644 - val_mse: 0.0141 - val_rmse: 0.1188 - learning_rate: 1.0000e-04
# Epoch 16/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0076 - mae: 0.0577 - mse: 0.0092 - rmse: 0.0957 - val_loss: 0.0084 - val_mae: 0.0622 - val_mse: 0.0109 - val_rmse: 0.1042 - learning_rate: 1.0000e-04
# Epoch 17/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0075 - mae: 0.0572 - mse: 0.0090 - rmse: 0.0949 - val_loss: 0.0081 - val_mae: 0.0570 - val_mse: 0.0103 - val_rmse: 0.1014 - learning_rate: 1.0000e-04
# Epoch 18/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0075 - mae: 0.0569 - mse: 0.0090 - rmse: 0.0946 - val_loss: 0.0077 - val_mae: 0.0573 - val_mse: 0.0095 - val_rmse: 0.0976 - learning_rate: 1.0000e-04
# Epoch 19/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0074 - mae: 0.0566 - mse: 0.0088 - rmse: 0.0940 - val_loss: 0.0082 - val_mae: 0.0646 - val_mse: 0.0105 - val_rmse: 0.1027 - learning_rate: 1.0000e-04
# Epoch 20/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0061 - mae: 0.0521 - mse: 0.0072 - rmse: 0.0850 - val_loss: 0.0055 - val_mae: 0.0504 - val_mse: 0.0069 - val_rmse: 0.0833 - learning_rate: 5.0000e-05
# Epoch 21/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 142s 28ms/step - loss: 0.0055 - mae: 0.0510 - mse: 0.0069 - rmse: 0.0829 - val_loss: 0.0056 - val_mae: 0.0534 - val_mse: 0.0072 - val_rmse: 0.0847 - learning_rate: 5.0000e-05
# Epoch 22/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0053 - mae: 0.0503 - mse: 0.0067 - rmse: 0.0819 - val_loss: 0.0056 - val_mae: 0.0473 - val_mse: 0.0073 - val_rmse: 0.0856 - learning_rate: 5.0000e-05
# Epoch 23/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0052 - mae: 0.0499 - mse: 0.0066 - rmse: 0.0811 - val_loss: 0.0052 - val_mae: 0.0515 - val_mse: 0.0065 - val_rmse: 0.0809 - learning_rate: 5.0000e-05
# Epoch 24/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0052 - mae: 0.0495 - mse: 0.0065 - rmse: 0.0806 - val_loss: 0.0052 - val_mae: 0.0504 - val_mse: 0.0066 - val_rmse: 0.0812 - learning_rate: 5.0000e-05
# Epoch 25/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0052 - mae: 0.0493 - mse: 0.0065 - rmse: 0.0805 - val_loss: 0.0055 - val_mae: 0.0510 - val_mse: 0.0071 - val_rmse: 0.0841 - learning_rate: 5.0000e-05
# Epoch 26/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 142s 28ms/step - loss: 0.0052 - mae: 0.0494 - mse: 0.0065 - rmse: 0.0805 - val_loss: 0.0052 - val_mae: 0.0506 - val_mse: 0.0066 - val_rmse: 0.0812 - learning_rate: 5.0000e-05
# Epoch 27/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0052 - mae: 0.0493 - mse: 0.0065 - rmse: 0.0804 - val_loss: 0.0057 - val_mae: 0.0495 - val_mse: 0.0075 - val_rmse: 0.0867 - learning_rate: 5.0000e-05
# Epoch 28/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0051 - mae: 0.0488 - mse: 0.0063 - rmse: 0.0796 - val_loss: 0.0055 - val_mae: 0.0486 - val_mse: 0.0072 - val_rmse: 0.0847 - learning_rate: 5.0000e-05
# Epoch 29/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0044 - mae: 0.0455 - mse: 0.0054 - rmse: 0.0733 - val_loss: 0.0041 - val_mae: 0.0430 - val_mse: 0.0051 - val_rmse: 0.0714 - learning_rate: 2.5000e-05
# Epoch 30/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0041 - mae: 0.0448 - mse: 0.0052 - rmse: 0.0718 - val_loss: 0.0041 - val_mae: 0.0447 - val_mse: 0.0052 - val_rmse: 0.0719 - learning_rate: 2.5000e-05
# Epoch 31/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0040 - mae: 0.0444 - mse: 0.0051 - rmse: 0.0711 - val_loss: 0.0043 - val_mae: 0.0475 - val_mse: 0.0057 - val_rmse: 0.0757 - learning_rate: 2.5000e-05
# Epoch 32/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0039 - mae: 0.0443 - mse: 0.0050 - rmse: 0.0709 - val_loss: 0.0040 - val_mae: 0.0432 - val_mse: 0.0052 - val_rmse: 0.0721 - learning_rate: 2.5000e-05
# Epoch 33/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0039 - mae: 0.0439 - mse: 0.0049 - rmse: 0.0703 - val_loss: 0.0044 - val_mae: 0.0453 - val_mse: 0.0061 - val_rmse: 0.0780 - learning_rate: 2.5000e-05
# Epoch 34/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0039 - mae: 0.0439 - mse: 0.0049 - rmse: 0.0702 - val_loss: 0.0041 - val_mae: 0.0435 - val_mse: 0.0054 - val_rmse: 0.0734 - learning_rate: 2.5000e-05
# Epoch 35/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0035 - mae: 0.0418 - mse: 0.0044 - rmse: 0.0663 - val_loss: 0.0034 - val_mae: 0.0403 - val_mse: 0.0042 - val_rmse: 0.0651 - learning_rate: 1.2500e-05
# Epoch 36/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0034 - mae: 0.0414 - mse: 0.0043 - rmse: 0.0653 - val_loss: 0.0034 - val_mae: 0.0396 - val_mse: 0.0043 - val_rmse: 0.0658 - learning_rate: 1.2500e-05
# Epoch 37/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0033 - mae: 0.0411 - mse: 0.0042 - rmse: 0.0648 - val_loss: 0.0034 - val_mae: 0.0405 - val_mse: 0.0044 - val_rmse: 0.0666 - learning_rate: 1.2500e-05
# Epoch 38/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0033 - mae: 0.0411 - mse: 0.0042 - rmse: 0.0646 - val_loss: 0.0036 - val_mae: 0.0408 - val_mse: 0.0050 - val_rmse: 0.0705 - learning_rate: 1.2500e-05
# Epoch 39/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0032 - mae: 0.0408 - mse: 0.0041 - rmse: 0.0644 - val_loss: 0.0033 - val_mae: 0.0396 - val_mse: 0.0043 - val_rmse: 0.0657 - learning_rate: 1.2500e-05
# Epoch 40/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0032 - mae: 0.0407 - mse: 0.0041 - rmse: 0.0640 - val_loss: 0.0033 - val_mae: 0.0399 - val_mse: 0.0043 - val_rmse: 0.0655 - learning_rate: 1.2500e-05
# Epoch 41/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0030 - mae: 0.0395 - mse: 0.0038 - rmse: 0.0618 - val_loss: 0.0030 - val_mae: 0.0379 - val_mse: 0.0039 - val_rmse: 0.0621 - learning_rate: 6.2500e-06
# Epoch 42/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0030 - mae: 0.0394 - mse: 0.0038 - rmse: 0.0613 - val_loss: 0.0031 - val_mae: 0.0384 - val_mse: 0.0040 - val_rmse: 0.0633 - learning_rate: 6.2500e-06
# Epoch 43/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0029 - mae: 0.0390 - mse: 0.0037 - rmse: 0.0609 - val_loss: 0.0030 - val_mae: 0.0382 - val_mse: 0.0039 - val_rmse: 0.0625 - learning_rate: 6.2500e-06
# Epoch 44/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0029 - mae: 0.0389 - mse: 0.0037 - rmse: 0.0607 - val_loss: 0.0030 - val_mae: 0.0390 - val_mse: 0.0039 - val_rmse: 0.0627 - learning_rate: 6.2500e-06
# Epoch 45/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 98s 28ms/step - loss: 0.0029 - mae: 0.0388 - mse: 0.0037 - rmse: 0.0604 - val_loss: 0.0030 - val_mae: 0.0380 - val_mse: 0.0038 - val_rmse: 0.0618 - learning_rate: 6.2500e-06
# Epoch 46/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0029 - mae: 0.0388 - mse: 0.0037 - rmse: 0.0604 - val_loss: 0.0030 - val_mae: 0.0385 - val_mse: 0.0039 - val_rmse: 0.0621 - learning_rate: 6.2500e-06
# Epoch 47/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0028 - mae: 0.0383 - mse: 0.0035 - rmse: 0.0594 - val_loss: 0.0028 - val_mae: 0.0373 - val_mse: 0.0037 - val_rmse: 0.0606 - learning_rate: 3.1250e-06
# Epoch 48/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0027 - mae: 0.0379 - mse: 0.0034 - rmse: 0.0587 - val_loss: 0.0028 - val_mae: 0.0372 - val_mse: 0.0037 - val_rmse: 0.0605 - learning_rate: 3.1250e-06
# Epoch 49/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0027 - mae: 0.0378 - mse: 0.0034 - rmse: 0.0586 - val_loss: 0.0029 - val_mae: 0.0373 - val_mse: 0.0037 - val_rmse: 0.0611 - learning_rate: 3.1250e-06
# Epoch 50/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0027 - mae: 0.0378 - mse: 0.0034 - rmse: 0.0585 - val_loss: 0.0028 - val_mae: 0.0380 - val_mse: 0.0036 - val_rmse: 0.0601 - learning_rate: 3.1250e-06
# Epoch 51/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0027 - mae: 0.0377 - mse: 0.0034 - rmse: 0.0584 - val_loss: 0.0028 - val_mae: 0.0372 - val_mse: 0.0037 - val_rmse: 0.0606 - learning_rate: 3.1250e-06
# Epoch 52/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0027 - mae: 0.0377 - mse: 0.0034 - rmse: 0.0582 - val_loss: 0.0028 - val_mae: 0.0373 - val_mse: 0.0037 - val_rmse: 0.0606 - learning_rate: 3.1250e-06
# Epoch 53/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0026 - mae: 0.0372 - mse: 0.0033 - rmse: 0.0575 - val_loss: 0.0028 - val_mae: 0.0369 - val_mse: 0.0036 - val_rmse: 0.0598 - learning_rate: 1.5625e-06
# Epoch 54/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0026 - mae: 0.0374 - mse: 0.0033 - rmse: 0.0577 - val_loss: 0.0028 - val_mae: 0.0370 - val_mse: 0.0036 - val_rmse: 0.0597 - learning_rate: 1.5625e-06
# Epoch 55/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0026 - mae: 0.0372 - mse: 0.0033 - rmse: 0.0574 - val_loss: 0.0028 - val_mae: 0.0369 - val_mse: 0.0036 - val_rmse: 0.0598 - learning_rate: 1.5625e-06
# Epoch 56/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0026 - mae: 0.0373 - mse: 0.0033 - rmse: 0.0574 - val_loss: 0.0028 - val_mae: 0.0371 - val_mse: 0.0036 - val_rmse: 0.0597 - learning_rate: 1.5625e-06
# Epoch 57/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0026 - mae: 0.0372 - mse: 0.0033 - rmse: 0.0574 - val_loss: 0.0027 - val_mae: 0.0372 - val_mse: 0.0036 - val_rmse: 0.0597 - learning_rate: 1.5625e-06
# Epoch 58/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0026 - mae: 0.0371 - mse: 0.0033 - rmse: 0.0572 - val_loss: 0.0027 - val_mae: 0.0368 - val_mse: 0.0036 - val_rmse: 0.0598 - learning_rate: 1.5625e-06
# Epoch 59/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0026 - mae: 0.0371 - mse: 0.0033 - rmse: 0.0572 - val_loss: 0.0028 - val_mae: 0.0369 - val_mse: 0.0036 - val_rmse: 0.0601 - learning_rate: 1.5625e-06
# Epoch 60/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0026 - mae: 0.0372 - mse: 0.0033 - rmse: 0.0573 - val_loss: 0.0027 - val_mae: 0.0372 - val_mse: 0.0036 - val_rmse: 0.0597 - learning_rate: 1.5625e-06
# Epoch 61/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0026 - mae: 0.0372 - mse: 0.0033 - rmse: 0.0572 - val_loss: 0.0028 - val_mae: 0.0368 - val_mse: 0.0037 - val_rmse: 0.0604 - learning_rate: 1.5625e-06
# Epoch 62/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0026 - mae: 0.0370 - mse: 0.0032 - rmse: 0.0570 - val_loss: 0.0027 - val_mae: 0.0370 - val_mse: 0.0036 - val_rmse: 0.0598 - learning_rate: 1.5625e-06
# Epoch 63/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0026 - mae: 0.0368 - mse: 0.0032 - rmse: 0.0566 - val_loss: 0.0027 - val_mae: 0.0371 - val_mse: 0.0036 - val_rmse: 0.0596 - learning_rate: 7.8125e-07
# Epoch 64/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0368 - mse: 0.0032 - rmse: 0.0565 - val_loss: 0.0027 - val_mae: 0.0369 - val_mse: 0.0036 - val_rmse: 0.0596 - learning_rate: 7.8125e-07
# Epoch 65/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0026 - mae: 0.0368 - mse: 0.0032 - rmse: 0.0566 - val_loss: 0.0027 - val_mae: 0.0367 - val_mse: 0.0036 - val_rmse: 0.0596 - learning_rate: 7.8125e-07
# Epoch 66/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0032 - rmse: 0.0565 - val_loss: 0.0027 - val_mae: 0.0367 - val_mse: 0.0036 - val_rmse: 0.0597 - learning_rate: 7.8125e-07
# Epoch 67/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 142s 28ms/step - loss: 0.0025 - mae: 0.0366 - mse: 0.0032 - rmse: 0.0564 - val_loss: 0.0027 - val_mae: 0.0368 - val_mse: 0.0035 - val_rmse: 0.0596 - learning_rate: 7.8125e-07
# Epoch 68/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0368 - mse: 0.0032 - rmse: 0.0566 - val_loss: 0.0027 - val_mae: 0.0367 - val_mse: 0.0035 - val_rmse: 0.0595 - learning_rate: 3.9062e-07
# Epoch 69/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0366 - mse: 0.0032 - rmse: 0.0563 - val_loss: 0.0027 - val_mae: 0.0367 - val_mse: 0.0035 - val_rmse: 0.0595 - learning_rate: 3.9062e-07
# Epoch 70/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0366 - mse: 0.0032 - rmse: 0.0562 - val_loss: 0.0027 - val_mae: 0.0368 - val_mse: 0.0035 - val_rmse: 0.0595 - learning_rate: 3.9062e-07
# Epoch 71/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0032 - rmse: 0.0563 - val_loss: 0.0027 - val_mae: 0.0368 - val_mse: 0.0035 - val_rmse: 0.0594 - learning_rate: 3.9062e-07
# Epoch 72/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0032 - rmse: 0.0565 - val_loss: 0.0027 - val_mae: 0.0367 - val_mse: 0.0035 - val_rmse: 0.0595 - learning_rate: 3.9062e-07
# Epoch 73/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0366 - mse: 0.0032 - rmse: 0.0562 - val_loss: 0.0027 - val_mae: 0.0367 - val_mse: 0.0035 - val_rmse: 0.0594 - learning_rate: 1.9531e-07
# Epoch 74/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0366 - mse: 0.0031 - rmse: 0.0561 - val_loss: 0.0027 - val_mae: 0.0366 - val_mse: 0.0035 - val_rmse: 0.0594 - learning_rate: 1.9531e-07
# Epoch 75/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0365 - mse: 0.0032 - rmse: 0.0562 - val_loss: 0.0027 - val_mae: 0.0366 - val_mse: 0.0035 - val_rmse: 0.0595 - learning_rate: 1.9531e-07
# Epoch 76/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0366 - mse: 0.0032 - rmse: 0.0562 - val_loss: 0.0027 - val_mae: 0.0367 - val_mse: 0.0035 - val_rmse: 0.0594 - learning_rate: 1.9531e-07
# Epoch 77/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0366 - mse: 0.0032 - rmse: 0.0562 - val_loss: 0.0027 - val_mae: 0.0368 - val_mse: 0.0035 - val_rmse: 0.0593 - learning_rate: 1.9531e-07
# Epoch 78/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0366 - mse: 0.0031 - rmse: 0.0560 - val_loss: 0.0027 - val_mae: 0.0367 - val_mse: 0.0035 - val_rmse: 0.0594 - learning_rate: 1.0000e-07
# Epoch 79/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 142s 28ms/step - loss: 0.0025 - mae: 0.0365 - mse: 0.0031 - rmse: 0.0561 - val_loss: 0.0027 - val_mae: 0.0367 - val_mse: 0.0035 - val_rmse: 0.0594 - learning_rate: 1.0000e-07
# Epoch 80/80
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 97s 28ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0032 - rmse: 0.0563 - val_loss: 0.0027 - val_mae: 0.0367 - val_mse: 0.0035 - val_rmse: 0.0594 - learning_rate: 1.0000e-07

# %%
plt.figure(figsize=(20, 10))
# Plot the training and validation loss
plt.subplot(2, 2, 1)
plt.plot(saliency_model.history['loss'][0:])
plt.plot(saliency_model.history['val_loss'][0:])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(2, 2, 2)
plt.plot(saliency_model.history['mse'][0:])
plt.plot(saliency_model.history['val_mse'][0:])
plt.title('Model MSE')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(2, 2, 3)
plt.plot(saliency_model.history['mae'][0:])
plt.plot(saliency_model.history['val_mae'][0:])
plt.title('Model MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(2, 2, 4)
plt.plot(saliency_model.history['rmse'][0:])
plt.plot(saliency_model.history['val_rmse'][0:])
plt.title('Model RMSE')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
model.save('../saved-models/optimized-model-64.h5')

# %%
import gc
del X_train 
del y_train
gc.collect()
# Out:
# 15962

# %%
# evaluate model
X_test = np.concatenate([np.load(f).astype(np.uint8) for f in val_files])
y_test = np.concatenate([np.loadtxt(f"../3d-meshes/{os.path.basename(f).replace('.npy', '.txt')}").astype(np.float32) for f in val_files])
loss, mse, mae, rmse = model.evaluate(X_test, y_test, verbose=1)
print("Loss: ", loss)
print("MSE: ", mse)
print("MAE: ", mae)
print("RMSE: ", rmse)
# Out:
#   67/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.0055 - mae: 0.0446 - mse: 0.0090 - rmse: 0.0949
# W0000 00:00:1723942383.367470      82 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0070 - mae: 0.0585 - mse: 0.0121 - rmse: 0.1096
# Loss:  0.00916334055364132
# MSE:  0.01644953526556492
# MAE:  0.07499247044324875
# RMSE:  0.12825573980808258
